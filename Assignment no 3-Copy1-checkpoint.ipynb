# %%
poem = ("TWINKLE TWINKLE LITTLE STAR\n    HOW I WONDER WHAT YOU ARE\n        UP ABOUT THE WORLD SO HIGH\n        LIKE A DIAMOND IN THE SKY\nTWINKLE TWINKLE LITTLE STAR\n    HOW I WONDER WHAT YOU ARE")
print(poem);
# Out:
# TWINKLE TWINKLE LITTLE STAR
#     HOW I WONDER WHAT YOU ARE
#         UP ABOUT THE WORLD SO HIGH
#         LIKE A DIAMOND IN THE SKY
# TWINKLE TWINKLE LITTLE STAR
#     HOW I WONDER WHAT YOU ARE

# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2021-10-24

# %%
Radius = 0.6
pi = 3.142
Area = Radius*pi
print("Area of the circle is", Area);
# Out:
# Area of the circle is 1.8851999999999998

# %%
name = "fiza shakil"[::-1];
print(name);
# Out:
# likahs azif

# %%
a = "Fiza"
b = "Shakil"
x = a + b
print(x);
# Out:
# FizaShakil

# %%
english = 80;
maths = 90;
science = 82;
islamiat = 70;
p_st = 89;
obtainedmarks =english + maths + science + islamiat + p_st;
total=500

percentage=(obtainedmarks/total)*100;

grade="";
if percentage < 100 and percentage>=80:
 grade="A+"
elif percentage < 80 and percentage>=70:
     grade="A";
elif percentage < 70 and percentage>=60:
     grade="B";
elif percentage < 60 and percentage>=50:
     grade="C";
elif perecentage < 50 and percentage>=40:
    grade="D";
elif percentage < 40 and percentage>=30:
    grade="Fail";
print("Name: Fiza Shakil")
print("Total Marks",total);
print("Obtained Marks", obtainedmarks);
print("Your Percentage is",percentage);
print("Your grade is",grade);
# Out:
# Name: Fiza Shakil
# Total Marks 500
# Obtained Marks 411
# Your Percentage is 82.19999999999999
# Your grade is A+

# %%
# Python program to check if the input number is odd or even.

num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 69
# 69 is Odd

# %%
list1 = ["Dua", "Nafeesa", "Fiza", "Afifa", "Hafsa Naz"];
print("Length of the list is", len(list1));
# Out:
# Length of the list is 5

# %%
list2 = [1,3,6,7,8,9];
print(sum(list2));
# Out:
# 34

# %%
list2 = [1,3,6,7,8,9];
print(max(list2));
# Out:
# 9

# %%
list1 = [12, 1, 2, 32, 5, 8, 123, 221, 324, 525, 892]  #list

for ar in list1: 
 if ar < 10:

   print(ar)
